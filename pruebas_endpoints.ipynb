# %%
import pyarrow
import pandas as pd
import numpy as np

# %%
endpoint_developer = pd.read_parquet('data_games.parquet')

# %%
endpoint_developer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29782 entries, 0 to 29781
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   genres          28548 non-null  object
#  1   app_name        29782 non-null  object
#  2   title           29782 non-null  object
#  3   release_date    29782 non-null  datetime64[ns]
#  4   discount_price  29782 non-null  float64
#  5   price           29782 non-null  float64
#  6   developer       28533 non-null  object
# dtypes: datetime64[ns](1), float64(2), object(4)
# memory usage: 1.6+ MB

# %%
endpoint_developer['year'] = endpoint_developer['release_date'].dt.year
endpoint_developer['month'] = endpoint_developer['release_date'].dt.month
endpoint_developer['day'] = endpoint_developer['release_date'].dt.day

# %%
endpoint_developer
# Out:
#                                                   genres  \
# 0          [Action, Casual, Indie, Simulation, Strategy]
# 1                   [Free to Play, Indie, RPG, Strategy]
# 2      [Casual, Free to Play, Indie, Simulation, Sports]
# 3                            [Action, Adventure, Casual]
# 4                        [Action, Adventure, Simulation]
# ...                                                  ...
# 29777                 [Action, Adventure, Casual, Indie]
# 29778              [Casual, Indie, Simulation, Strategy]
# 29779                          [Casual, Indie, Strategy]
# 29780                        [Indie, Racing, Simulation]
# 29781                                    [Casual, Indie]
#
#                        app_name                     title release_date  \
# 0           Lost Summoner Kitty       Lost Summoner Kitty   2018-01-04
# 1                     Ironbound                 Ironbound   2018-01-04
# 2       Real Pool 3D - Poolians   Real Pool 3D - Poolians   2017-07-24
# 3                       弹炸人2222                   弹炸人2222   2017-12-07
# 4         Battle Royale Trainer     Battle Royale Trainer   2018-01-04
# ...                         ...                       ...          ...
# 29777              Kebab it Up!              Kebab it Up!   2018-01-04
# 29778            Colony On Mars            Colony On Mars   2018-01-04
# 29779  LOGistICAL: South Africa  LOGistICAL: South Africa   2018-01-04
# 29780             Russian Roads             Russian Roads   2018-01-04
# 29781       EXIT 2 - Directions       EXIT 2 - Directions   2017-09-02
#
#        discount_price  price                 developer  year  month  day
# 0                4.49   4.99                 Kotoshiro  2018      1    4
# 1                0.00   0.00          Secret Level SRL  2018      1    4
# 2                0.00   0.00              Poolians.com  2017      7   24
# 3                0.83   0.99                      彼岸领域  2017     12    7
# 4                0.00   3.99       Trickjump Games Ltd  2018      1    4
# ...               ...    ...                       ...   ...    ...  ...
# 29777            1.69   1.99           Bidoniera Games  2018      1    4
# 29778            1.49   1.99        Nikita "Ghost_RUS"  2018      1    4
# 29779            4.24   4.99                    Sacada  2018      1    4
# 29780            1.39   1.99  Laush Dmitriy Sergeevich  2018      1    4
# 29781            0.00   4.99             xropi,stev3ns  2017      9    2
#
# [29782 rows x 10 columns]

# %%
def dev_name(developer : str):
    
    juegos_valor_cero = endpoint_developer[(endpoint_developer['developer'] == developer) & (endpoint_developer['price'] == 0)]

    agrupado = juegos_valor_cero.groupby('year')['developer'].count().reset_index(name='juegos_valor_cero')
    total_juegos_por_anio = endpoint_developer[endpoint_developer['developer'] == developer].groupby('year')['developer'].count().reset_index(name='total_juegos')

    resultado = pd.merge(agrupado, total_juegos_por_anio, on='year')
    resultado['Contenido Free'] = (resultado.juegos_valor_cero/resultado.total_juegos)*100
    resultado.drop(columns=['juegos_valor_cero', 'total_juegos'], inplace=True)

    return resultado

# %%
resultado
# Out:
#    year  juegos_valor_cero  total_juegos  Contenido Free
# 0  2012                  1           114        0.877193

# %%
dev_name('Ubisoft - San Francisco')
# Out:
#    year  Contenido Free
# 0  2012        0.877193

# %%
data_users = pd.read_parquet('users_data.parquet')

# %%
data_users
# Out:
#                  user_id                                              items  \
# 0      76561197970982479  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 1                js41637  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 2              evcentric  [{'item_id': '1200', 'item_name': 'Red Orchest...
# 3                  doctr  [{'item_id': '300', 'item_name': 'Day of Defea...
# 4              maplemage  [{'item_id': '240', 'item_name': 'Counter-Stri...
# ...                  ...                                                ...
# 26430  76561198306599751  [{'item_id': '4000', 'item_name': "Garry's Mod...
# 26431           Ghoustik  [{'item_id': '302830', 'item_name': 'BLOCKADE ...
# 26432  76561198310819422  [{'item_id': '268420', 'item_name': 'Aura King...
# 26433  76561198312638244  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 26434        LydiaMorley                                                 []
#
#                                               user_url_y  \
# 0      http://steamcommunity.com/profiles/76561197970...
# 1                   http://steamcommunity.com/id/js41637
# 2                 http://steamcommunity.com/id/evcentric
# 3                     http://steamcommunity.com/id/doctr
# 4                 http://steamcommunity.com/id/maplemage
# ...                                                  ...
# 26430  http://steamcommunity.com/profiles/76561198306...
# 26431              http://steamcommunity.com/id/Ghoustik
# 26432  http://steamcommunity.com/profiles/76561198310...
# 26433  http://steamcommunity.com/profiles/76561198312...
# 26434           http://steamcommunity.com/id/LydiaMorley
#
#                                                  reviews
# 0      [{'funny': '', 'posted': 'Posted November 5, 2...
# 1      [{'funny': '', 'posted': 'Posted June 24, 2014...
# 2      [{'funny': '', 'posted': 'Posted February 3.',...
# 3      [{'funny': '', 'posted': 'Posted October 14, 2...
# 4      [{'funny': '3 people found this review funny',...
# ...                                                  ...
# 26430  [{'funny': '', 'posted': 'Posted May 31.', 'la...
# 26431  [{'funny': '', 'posted': 'Posted June 17.', 'l...
# 26432  [{'funny': '1 person found this review funny',...
# 26433  [{'funny': '', 'posted': 'Posted July 21.', 'l...
# 26434  [{'funny': '1 person found this review funny',...
#
# [26435 rows x 4 columns]

# %%
items = pd.read_parquet('user_items.parquet')

# %%
items
# Out:
#                        user_id  \
# 0            76561197970982479
# 1                      js41637
# 2                    evcentric
# 3                   Riot-Punch
# 4                        doctr
# ...                        ...
# 88305        76561198323066619
# 88306        76561198326700687
# 88307  XxLaughingJackClown77xX
# 88308        76561198329548331
# 88309        edward_tremethick
#
#                                                 user_url  \
# 0      http://steamcommunity.com/profiles/76561197970...
# 1                   http://steamcommunity.com/id/js41637
# 2                 http://steamcommunity.com/id/evcentric
# 3                http://steamcommunity.com/id/Riot-Punch
# 4                     http://steamcommunity.com/id/doctr
# ...                                                  ...
# 88305  http://steamcommunity.com/profiles/76561198323...
# 88306  http://steamcommunity.com/profiles/76561198326...
# 88307  http://steamcommunity.com/id/XxLaughingJackClo...
# 88308  http://steamcommunity.com/profiles/76561198329...
# 88309     http://steamcommunity.com/id/edward_tremethick
#
#                                                    items
# 0      [{'item_id': '10', 'item_name': 'Counter-Strik...
# 1      [{'item_id': '10', 'item_name': 'Counter-Strik...
# 2      [{'item_id': '1200', 'item_name': 'Red Orchest...
# 3      [{'item_id': '10', 'item_name': 'Counter-Strik...
# 4      [{'item_id': '300', 'item_name': 'Day of Defea...
# ...                                                  ...
# 88305  [{'item_id': '413850', 'item_name': 'CS:GO Pla...
# 88306  [{'item_id': '11020', 'item_name': 'TrackMania...
# 88307                                                 []
# 88308  [{'item_id': '304930', 'item_name': 'Unturned'...
# 88309                                                 []
#
# [88310 rows x 3 columns]
